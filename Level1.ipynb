# %%
import pandas as pd

# %%
df = pd.read_csv('data\weatherAUS.csv')

# %%
pd.set_option('display.max_columns', 23)

# %%
df
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 0       2008-12-01   Albury     13.4     22.9       0.6          NaN
# 1       2008-12-02   Albury      7.4     25.1       0.0          NaN
# 2       2008-12-03   Albury     12.9     25.7       0.0          NaN
# 3       2008-12-04   Albury      9.2     28.0       0.0          NaN
# 4       2008-12-05   Albury     17.5     32.3       1.0          NaN
# ...            ...      ...      ...      ...       ...          ...
# 145455  2017-06-21    Uluru      2.8     23.4       0.0          NaN
# 145456  2017-06-22    Uluru      3.6     25.3       0.0          NaN
# 145457  2017-06-23    Uluru      5.4     26.9       0.0          NaN
# 145458  2017-06-24    Uluru      7.8     27.0       0.0          NaN
# 145459  2017-06-25    Uluru     14.9      NaN       0.0          NaN
#
#         Sunshine WindGustDir  WindGustSpeed WindDir9am WindDir3pm  \
# 0            NaN           W           44.0          W        WNW
# ...

# %%
df['MaxTemp'].mean() #Average Maximum Temperature
# Out:
# 23.22134827564685

# %%
df['MinTemp'].mean() #Average Minimum Temperature
# Out:
# 12.19403438096892

# %%
 filt = (df['Location'] == 'Cobar')

# %%
df.loc[filt]
# Out:
#             Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 6049  2009-01-01    Cobar     17.9     35.2       0.0         12.0      12.3
# 6050  2009-01-02    Cobar     18.4     28.9       0.0         14.8      13.0
# 6051  2009-01-03    Cobar     15.5     34.1       0.0         12.6      13.3
# 6052  2009-01-04    Cobar     19.4     37.6       0.0         10.8      10.6
# 6053  2009-01-05    Cobar     21.9     38.4       0.0         11.4      12.2
# ...          ...      ...      ...      ...       ...          ...       ...
# 9053  2017-06-21    Cobar      5.8     19.1       0.0          NaN       NaN
# 9054  2017-06-22    Cobar      2.8     19.2       0.0          NaN       NaN
# 9055  2017-06-23    Cobar      6.9     20.0       0.0          NaN       NaN
# 9056  2017-06-24    Cobar      8.3     16.2       0.0          NaN       NaN
# 9057  2017-06-25    Cobar      9.1     22.0       0.0          NaN       NaN
#
# ...

# %%
df.loc[filt]['MaxTemp'].mean() #Average Maximum Temperature in the Location Cobar
# Out:
# 25.870093147039256

# %%
145460 - df['Sunshine'].count() #count of null value in the column → Sunshine
# Out:
# 69835

# %%
145460 - df['Evaporation'].count() #count of null value in the column →  Evaporation
# Out:
# 62790
